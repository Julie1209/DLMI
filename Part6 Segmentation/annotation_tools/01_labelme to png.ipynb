# %%
# !pip install fusionlab

# %%
from fusionlab.utils import convert_labelme_json2mask

# %%
convert_labelme_json2mask(
    class_names=['bg', 'kidney', 'tumor'],
    json_dir="json",
    output_dir="mask",
    single_mask=True,
)

# %%
import matplotlib.pyplot as plt
import cv2

mask = cv2.imread("mask/seg1.png")[:, :, 0]
mask.shape

# %%
plt.imshow(mask)

# %%
import numpy as np

np.unique(mask.reshape(-1))
